# %%
import pandas as pd

# %%
df = pd.read_csv('wssinfo_data_cleaned.csv')

# %%
df.head()
# Out:
#        Country  Year  Population Urban (x1000)  Population Urban (% Total)  \
# 0  Afghanistan  1990                    2130.0                        18.2
# 1  Afghanistan  1991                    2319.2                        18.4
# 2  Afghanistan  1992                    2572.3                        18.6
# 3  Afghanistan  1993                    2862.1                        18.9
# 4  Afghanistan  1994                    3148.5                        19.1
#
#    Population Rural (x1000)  Population Rural (% Total)  Population (x 1000)  \
# 0                    9601.2                        81.8              11731.2
# 1                   10292.8                        81.6              12612.0
# 2                   11239.6                        81.4              13811.9
# 3                   12313.3                        81.1              15175.3
# 4                   13336.5                        80.9              16485.0
#
# ...
